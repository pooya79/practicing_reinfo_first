# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install gym[box2d] pyglet
# Out:
# Requirement already satisfied: gym[box2d] in /home/pooya-fallah/python_envs/reinforce_practice/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: pyglet in /home/pooya-fallah/python_envs/reinforce_practice/lib/python3.10/site-packages (1.5.23)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/pooya-fallah/python_envs/reinforce_practice/lib/python3.10/site-packages (from gym[box2d]) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/pooya-fallah/python_envs/reinforce_practice/lib/python3.10/site-packages (from gym[box2d]) (1.22.3)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349309 sha256=54bde6348f8853af398f3e859b520eeeba9a3eb7ffb9c60d7a650cded1b94696
#   Stored in directory: /home/pooya-fallah/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1103..1390 -> 287-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       8     env.render()
#       9     action = env.action_space.sample()
# ---> 10     n_state, reward, done, info = env.step(action)
#      11     score+=reward
#      12 print('Episode:{} Score:{}'.format(episode, score))
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/wrappers/time_limit.py:18, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert (
#      16         self._elapsed_steps is not None
#      17     ), "Cannot call env.step() before calling reset()"
# ---> 18     observation, reward, done, info = self.env.step(action)
#      19     self._elapsed_steps += 1
#      20     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/envs/box2d/car_racing.py:377, in CarRacing.step(self, action)
#     374 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     375 self.t += 1.0 / FPS
# --> 377 self.state = self.render("state_pixels")
#     379 step_reward = 0
#     380 done = False
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/envs/box2d/car_racing.py:465, in CarRacing.render(self, mode)
#     463 self.viewer.onetime_geoms = []
#     464 t.disable()
# --> 465 self.render_indicators(WINDOW_W, WINDOW_H)
#     467 if mode == "human":
#     468     win.flip()
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/envs/box2d/car_racing.py:579, in CarRacing.render_indicators(self, W, H)
#     560     colors.extend([color[0], color[1], color[2], 1] * 4)
#     561     polygons.extend(
#     562         [
#     563             (place + 0) * s,
#    (...)
#     575         ]
#     576     )
#     578 true_speed = np.sqrt(
# --> 579     np.square(self.car.hull.linearVelocity[0])
#     580     + np.square(self.car.hull.linearVelocity[1])
#     581 )
#     583 vertical_ind(5, 0.02 * true_speed, (1, 1, 1))
#     584 vertical_ind(7, 0.01 * self.car.wheels[0].omega, (0.0, 0, 1))  # ABS sensors
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Train Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join("Training", 'logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Track generation: 1324..1659 -> 335-tiles track
# Logging to Training/logs/PPO_8
# Track generation: 1298..1627 -> 329-tiles track
# Track generation: 1100..1381 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1208..1517 -> 309-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 212  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 2           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008293638 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.004       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.11        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00738    |
# |    std                  | 0.998       |
# |    value_loss           | 0.47        |
# -----------------------------------------
# Track generation: 1133..1420 -> 287-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 3           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008634474 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00887    |
# |    std                  | 0.993       |
# |    value_loss           | 0.464       |
# -----------------------------------------
# Track generation: 1400..1754 -> 354-tiles track
# Track generation: 1289..1619 -> 330-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 4          |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00912696 |
# |    clip_fraction        | 0.0979     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.23      |
# |    explained_variance   | -0.00508   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.123      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00878   |
# |    std                  | 0.99       |
# |    value_loss           | 0.461      |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1053..1326 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 166        |
# |    iterations           | 5          |
# |    time_elapsed         | 61         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01076168 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.222      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0773     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 0.982      |
# |    value_loss           | 0.38       |
# ----------------------------------------
# Track generation: 1213..1520 -> 307-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 6           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010758437 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0922      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.193       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.98        |
# |    value_loss           | 0.472       |
# -----------------------------------------
# Track generation: 1202..1506 -> 304-tiles track
# Track generation: 1128..1414 -> 286-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 7           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016160704 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.968       |
# |    value_loss           | 0.472       |
# -----------------------------------------
# Track generation: 1194..1497 -> 303-tiles track
# Track generation: 1118..1409 -> 291-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 154        |
# |    iterations           | 8          |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02171145 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | -0.0109    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.111      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.956      |
# |    value_loss           | 0.427      |
# ----------------------------------------
# Track generation: 1097..1377 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1058..1329 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1119..1402 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 9           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023490865 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0912      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0353     |
# |    std                  | 0.94        |
# |    value_loss           | 0.413       |
# -----------------------------------------
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1191..1500 -> 309-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 10          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.026117494 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00709     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0337     |
# |    std                  | 0.926       |
# |    value_loss           | 0.38        |
# -----------------------------------------
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1051..1318 -> 267-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 11          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.027982056 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | -0.315      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0451     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.906       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# Track generation: 1189..1490 -> 301-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 12          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.030907761 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0339     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0375     |
# |    std                  | 0.897       |
# |    value_loss           | 0.156       |
# -----------------------------------------
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1129..1416 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 13          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.022645123 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.882       |
# |    value_loss           | 0.0954      |
# -----------------------------------------
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1118..1407 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 14          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.026281781 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0333     |
# |    std                  | 0.874       |
# |    value_loss           | 0.0888      |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 15         |
# |    time_elapsed         | 208        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03331174 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.83      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0175    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0345    |
# |    std                  | 0.866      |
# |    value_loss           | 0.101      |
# ----------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1156..1450 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 16          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.030522581 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0364     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.859       |
# |    value_loss           | 0.0471      |
# -----------------------------------------
# Track generation: 1272..1595 -> 323-tiles track
# Track generation: 1064..1338 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1123..1408 -> 285-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 17          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.040760785 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0247      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.851       |
# |    value_loss           | 0.0679      |
# -----------------------------------------
# Track generation: 1003..1258 -> 255-tiles track
# Track generation: 1144..1434 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 18          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.034035847 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0451     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.844       |
# |    value_loss           | 0.0486      |
# -----------------------------------------
# Track generation: 1106..1386 -> 280-tiles track
# Track generation: 1355..1698 -> 343-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 19         |
# |    time_elapsed         | 265        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04152348 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.72      |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0659    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0392    |
# |    std                  | 0.832      |
# |    value_loss           | 0.166      |
# ----------------------------------------
# Track generation: 1278..1602 -> 324-tiles track
# Track generation: 1221..1530 -> 309-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 146       |
# |    iterations           | 20        |
# |    time_elapsed         | 280       |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0312574 |
# |    clip_fraction        | 0.264     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.7      |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0461   |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.0298   |
# |    std                  | 0.83      |
# |    value_loss           | 0.0625    |
# ---------------------------------------
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1193..1495 -> 302-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 21          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.033137307 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0374     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 0.825       |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# Track generation: 964..1217 -> 253-tiles track
# Track generation: 1034..1297 -> 263-tiles track
# --------------------------------------
# | time/                   |          |
# |    fps                  | 145      |
# |    iterations           | 22       |
# |    time_elapsed         | 309      |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 0.037299 |
# |    clip_fraction        | 0.288    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.67    |
# |    explained_variance   | 0.973    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0593  |
# |    n_updates            | 210      |
# |    policy_gradient_loss | -0.0372  |
# |    std                  | 0.821    |
# |    value_loss           | 0.0554   |
# --------------------------------------
# Track generation: 1259..1578 -> 319-tiles track
# Track generation: 1112..1402 -> 290-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 23         |
# |    time_elapsed         | 326        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.06190417 |
# |    clip_fraction        | 0.276      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0117    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.815      |
# |    value_loss           | 0.0932     |
# ----------------------------------------
# Track generation: 1040..1311 -> 271-tiles track
# Track generation: 1037..1303 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1188..1489 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 24         |
# |    time_elapsed         | 342        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.06203305 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.62      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00799   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0394    |
# |    std                  | 0.803      |
# |    value_loss           | 0.102      |
# ----------------------------------------
# Track generation: 1057..1325 -> 268-tiles track
# Track generation: 1165..1460 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 25          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.039612893 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00634    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0312     |
# |    std                  | 0.796       |
# |    value_loss           | 0.159       |
# -----------------------------------------
# Track generation: 998..1264 -> 266-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 26         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.07473725 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0769    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0448    |
# |    std                  | 0.788      |
# |    value_loss           | 0.0893     |
# ----------------------------------------
# Track generation: 1212..1520 -> 308-tiles track
# Track generation: 1224..1542 -> 318-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 27          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.050081916 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0449     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0349     |
# |    std                  | 0.777       |
# |    value_loss           | 0.0603      |
# -----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1111..1400 -> 289-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 140        |
# |    iterations           | 28         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.08723404 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0.925      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0339    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0454    |
# |    std                  | 0.77       |
# |    value_loss           | 0.143      |
# ----------------------------------------
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 979..1236 -> 257-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 140        |
# |    iterations           | 29         |
# |    time_elapsed         | 422        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.07276887 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0307    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0402    |
# |    std                  | 0.764      |
# |    value_loss           | 0.0947     |
# ----------------------------------------
# Track generation: 1334..1672 -> 338-tiles track
# Track generation: 1036..1299 -> 263-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 30          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.049172673 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 0.76        |
# |    value_loss           | 0.094       |
# -----------------------------------------
# Track generation: 1213..1521 -> 308-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 139       |
# |    iterations           | 31        |
# |    time_elapsed         | 454       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0631412 |
# |    clip_fraction        | 0.406     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.41     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0387   |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.0356   |
# |    std                  | 0.751     |
# |    value_loss           | 0.134     |
# ---------------------------------------
# Track generation: 1060..1332 -> 272-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1072..1344 -> 272-tiles track
# Track generation: 1246..1562 -> 316-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 32          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.055332065 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0545     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.04       |
# |    std                  | 0.742       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# Track generation: 1176..1484 -> 308-tiles track
# Track generation: 1087..1364 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1258..1579 -> 321-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 33         |
# |    time_elapsed         | 486        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.06357892 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0447    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0535    |
# |    std                  | 0.738      |
# |    value_loss           | 0.0866     |
# ----------------------------------------
# Track generation: 1316..1649 -> 333-tiles track
# Track generation: 1129..1415 -> 286-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 34         |
# |    time_elapsed         | 503        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06626573 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0675    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0469    |
# |    std                  | 0.722      |
# |    value_loss           | 0.0498     |
# ----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1143..1433 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 35          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.080211386 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0649     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.05       |
# |    std                  | 0.718       |
# |    value_loss           | 0.107       |
# -----------------------------------------
# Track generation: 1254..1572 -> 318-tiles track
# Track generation: 1152..1452 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 137        |
# |    iterations           | 36         |
# |    time_elapsed         | 536        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.10622543 |
# |    clip_fraction        | 0.433      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0201    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0451    |
# |    std                  | 0.705      |
# |    value_loss           | 0.131      |
# ----------------------------------------
# Track generation: 1214..1530 -> 316-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 137        |
# |    iterations           | 37         |
# |    time_elapsed         | 552        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.06373273 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0482    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0406    |
# |    std                  | 0.698      |
# |    value_loss           | 0.12       |
# ----------------------------------------
# Track generation: 1293..1621 -> 328-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 38          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.053253032 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0351     |
# |    std                  | 0.692       |
# |    value_loss           | 0.073       |
# -----------------------------------------
# Track generation: 1159..1462 -> 303-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 39         |
# |    time_elapsed         | 584        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.06610337 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0437    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0428    |
# |    std                  | 0.685      |
# |    value_loss           | 0.147      |
# ----------------------------------------
# Track generation: 1046..1312 -> 266-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 40         |
# |    time_elapsed         | 601        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.08202542 |
# |    clip_fraction        | 0.393      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.063     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0504    |
# |    std                  | 0.668      |
# |    value_loss           | 0.0876     |
# ----------------------------------------
# Track generation: 1201..1505 -> 304-tiles track
# Track generation: 1225..1536 -> 311-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 135        |
# |    iterations           | 41         |
# |    time_elapsed         | 618        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08258551 |
# |    clip_fraction        | 0.436      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0535    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0402    |
# |    std                  | 0.663      |
# |    value_loss           | 0.0604     |
# ----------------------------------------
# Track generation: 1153..1445 -> 292-tiles track
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1244..1559 -> 315-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 135        |
# |    iterations           | 42         |
# |    time_elapsed         | 636        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.10820576 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0391    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.045     |
# |    std                  | 0.655      |
# |    value_loss           | 0.0594     |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1080..1354 -> 274-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 134        |
# |    iterations           | 43         |
# |    time_elapsed         | 652        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.08796871 |
# |    clip_fraction        | 0.441      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0496    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.649      |
# |    value_loss           | 0.0679     |
# ----------------------------------------
# Track generation: 1035..1304 -> 269-tiles track
# Track generation: 982..1235 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1013..1278 -> 265-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 134        |
# |    iterations           | 44         |
# |    time_elapsed         | 670        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.08321354 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0825    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0429    |
# |    std                  | 0.639      |
# |    value_loss           | 0.133      |
# ----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1027..1288 -> 261-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 45          |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.068491556 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0471     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0421     |
# |    std                  | 0.639       |
# |    value_loss           | 0.119       |
# -----------------------------------------
# Track generation: 1076..1356 -> 280-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 46         |
# |    time_elapsed         | 703        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.07310572 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0495    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0381    |
# |    std                  | 0.635      |
# |    value_loss           | 0.0931     |
# ----------------------------------------
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1212..1519 -> 307-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 47         |
# |    time_elapsed         | 720        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.07747315 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0254    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0228    |
# |    std                  | 0.638      |
# |    value_loss           | 0.0757     |
# ----------------------------------------
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1112..1394 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 48         |
# |    time_elapsed         | 736        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08048265 |
# |    clip_fraction        | 0.431      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0573    |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0355    |
# |    std                  | 0.635      |
# |    value_loss           | 0.146      |
# ----------------------------------------
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 994..1251 -> 257-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 133        |
# |    iterations           | 49         |
# |    time_elapsed         | 752        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.08922352 |
# |    clip_fraction        | 0.418      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0771    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0462    |
# |    std                  | 0.628      |
# |    value_loss           | 0.074      |
# ----------------------------------------

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join("Training", 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)

# %%
# load model
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# Track generation: 976..1224 -> 248-tiles track
# Track generation: 1040..1312 -> 272-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 evaluate_policy(model, env, n_eval_episodes=10, render=True)
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:87, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      85 while (episode_counts < episode_count_targets).any():
#      86     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
# ---> 87     observations, rewards, dones, infos = env.step(actions)
#      88     current_rewards += rewards
#      89     current_lengths += 1
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/wrappers/time_limit.py:18, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert (
#      16         self._elapsed_steps is not None
#      17     ), "Cannot call env.step() before calling reset()"
# ---> 18     observation, reward, done, info = self.env.step(action)
#      19     self._elapsed_steps += 1
#      20     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/envs/box2d/car_racing.py:377, in CarRacing.step(self, action)
#     374 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     375 self.t += 1.0 / FPS
# --> 377 self.state = self.render("state_pixels")
#     379 step_reward = 0
#     380 done = False
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/gym/envs/box2d/car_racing.py:441, in CarRacing.render(self, mode)
#     438 win.switch_to()
#     439 win.dispatch_events()
# --> 441 win.clear()
#     442 t = self.transform
#     443 if mode == "rgb_array":
#
# File ~/python_envs/reinforce_practice/lib/python3.10/site-packages/pyglet/window/__init__.py:1348, in BaseWindow.clear(self)
#    1342 def clear(self):
#    1343     """Clear the window.
#    1344
#    1345     This is a convenience method for clearing the color and depth
#    1346     buffer.  The window must be the active context (see `switch_to`).
#    1347     """
# -> 1348     gl.glClear(gl.GL_COLOR_BUFFER_BIT | gl.GL_DEPTH_BUFFER_BIT)
#
# KeyboardInterrupt:

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
